# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import control as ct
from sklearn.metrics import mean_squared_error


import scienceplots

# %config InlineBackend.figure_format="retina"
plt.style.use(["science", "notebook"])

SMALL_SIZE = 10
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)        
plt.rc('axes', titlesize=BIGGER_SIZE)  
plt.rc('axes', labelsize=MEDIUM_SIZE)
plt.rc('xtick', labelsize=SMALL_SIZE)  
plt.rc('ytick', labelsize=SMALL_SIZE)  
plt.rc('legend', fontsize=SMALL_SIZE)  
plt.rc('figure', titlesize=BIGGER_SIZE)

# %% [markdown]
# ## **Tabela 01**
#
# Para os níveis de tensão $V_{cc}$ , indicados na tabela 7.1, preencha os valores associados para $I_a$ , $I_c$ , $E_a$ e rpm.

# %%
V = [0, 36, 72, 108, 144, 161]

Ia = [0, 1.62, 0.96, 0.80, 0.82, 0.87]
Ic = [0, 1.62, 1.06, 0.98, 1.06, 1.13]
Ea = [0, 34.6, 71, 107.5, 143.5, 160.4]
rpm = [0, 902, 1180, 1356, 1553, 1655]

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(V[1:], Ia[1:], c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('Corrente Ia', fontsize=10)
plt.xlabel('Tensão (V)', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(V[1:], Ic[1:], c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('Corrente Ic', fontsize=10)
plt.xlabel('Tensão (V)', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(V[1:], Ea[1:], c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('Tensão Ea', fontsize=10)
plt.xlabel('Tensão (V)', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(V[1:], rpm[1:], c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('RPM', fontsize=10)
plt.xlabel('Tensão (V)', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %% [markdown]
# ___
#
# ## **Tabela 02**

# %%
Re = [0, 20, 40, 60, 80, 100]

Ia1 = [0.87, 0.80, 0.78, 0.80, 1.65, 1.33]
Ic1 = [1.13, 1.02, 0.94, 0.94, 1.66, 1.30]
Ea1 = [160, 134, 106, 87, 4.4, 0]
rpm1 = [1653, 1487, 1335, 1203, 0, 0]

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(Re, Ia1, c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('Corrente Ia', fontsize=10)
plt.xlabel('Resistência Re', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(Re, Ic1, c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('Corrente Ic', fontsize=10)
plt.xlabel('Resistência Re', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(Re, Ea1, c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('Tensão Ea', fontsize=10)
plt.xlabel('Resistência Re', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(Re, rpm1, c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('RPM', fontsize=10)
plt.xlabel('Resistência Re', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %% [markdown]
# ___
#
# ## **Tabela 03**

# %%
Re = [0, 20, 40, 60, 80, 100]

Ia2 = [0.81, 0.82, 0.8, 0.78, 0.76, 0.74]
Ic2 = [1.12, 1.08, 1.04, 1.01, 0.99, 0.90]
Ea2 = [160, 138, 117, 98, 79, 64]
rpm2 = [1659, 1445, 1231, 1042, 845, 671]

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(Re, Ia2, c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('Corrente Ia', fontsize=10)
plt.xlabel('Resistência Re', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(Re, Ic2, c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('Corrente Ic', fontsize=10)
plt.xlabel('Resistência Re', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(Re, Ea2, c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('Tensão Ea', fontsize=10)
plt.xlabel('Resistência Re', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(Re, rpm2, c = 'b', label = "Sinal de Entrada PRBS")


plt. title('Ensaio PRBS', fontsize=12)
plt.ylabel('RPM', fontsize=10)
plt.xlabel('Resistência Re', fontsize=10)
#plt.legend(fontsize=10, loc="center right")

plt.grid(which='both')
plt.grid(which='major', color='#CCCCCC', linestyle='-', alpha=1)
plt.grid(which='minor', color='#CCCCCC', linestyle=':', alpha=0.5)

plt.show()
